# %%
import re
import pandas as pd
import numpy as np

# %%
with open("iif_test.iif") as file:
    data_list = file.readlines()

# %%
print(f">>>This iif file contains {len(data_list)} lines<<<\n")
for i in range(24):
    print(repr(data_list[i]))
# Out:
# >>>This iif file contains 263 lines<<<
#
# '!ACCNT\tNAME\tACCNTTYPE\tDESC\n'
# '!CLASS\tNAME\n'
# '\n'
# '!TRNS\tTRNSID\tDOCNUM\tTRNSTYPE\tDATE\tACCNT\tAMOUNT\tMEMO\tTOPRINT\tNAME\tCLASS\n'
# '!SPL\tSPLID\tDOCNUM\tTRNSTYPE\tDATE\tACCNT\tAMOUNT\tMEMO\tCLASS\n'
# '!ENDTRNS\n'
# '\n'
# 'ACCNT\tPayroll Expenses:Wages\tEXP\tWage Account - Employee Gross Pay\n'
# 'ACCNT\tBusiness Checking\tBANK\tChecking Account - Payroll\n'
# 'ACCNT\tPayroll Liabilities:MO Income Tax\tOCLIAB\tPayee Account - Total Taxes\n'
# 'ACCNT\tPayroll Liabilities:MO Local Tax\tOCLIAB\tPayee Account - Total Taxes\n'
# 'ACCNT\tPayroll Liabilities:Federal Unemployment (940)\tOCLIAB\tPayee Account - Total Taxes\n'
# 'ACCNT\tPayroll Liabilities:Federal Taxes (941/944)\tOCLIAB\tPayee Account - Total Taxes\n'
# 'ACCNT\tPayroll Liabilities:MO Unemployment Tax\tOCLIAB\tPayee Account - Total Taxes\n'
# 'ACCNT\tPayroll Expenses:Taxes\tEXP\tTax Account - Employer Taxes\n'
# 'TRNS\t\t\tCheck\t12/20/2021\tBusiness Checking\t-1622.33\tPay Period: 12/13/2021-12/19/2021\tN\tJean-Luc Picard\t\n'
# 'SPL\t\t\tCheck\t12/20/2021\tPayroll Expenses:Wages\t423.08\tGross Pay - This is not a legal pay stub\t\n'
# 'SPL\t\t\tCheck\t12/20/2021\tPayroll Expenses:Taxes\t50.62\tEmployer Taxes\t\n'
# 'SPL\t\t\tCheck\t12/20/2021\tPayroll Liabilities:MO Local Tax\t-29.23\tMO Local Tax\t\n'
# 'SPL\t\t\tCheck\t12/20/2021\tPayroll Liabilities:MO Unemployment Tax\t0.00\tMO Unemployment Tax\t\n'
# 'SPL\t\t\tCheck\t12/20/2021\tPayroll Liabilities:Federal Unemployment (940)\t0.00\tFederal Unemployment (940)\t\n'
# 'SPL\t\t\tCheck\t12/20/2021\tPayroll Liabilities:MO Income Tax\t-43.00\tMO Income Tax\t\n'
# 'SPL\t\t\tCheck\t12/20/2021\tPayroll Liabilities:Federal Taxes (941/944)\t-269.14\tFederal Taxes (941/944)\t\n'
# 'ENDTRNS\n'

# %%
for i in range(15,24):
    print(data_list[i])
# Out:
# TRNS			Check	12/20/2021	Business Checking	-1622.33	Pay Period: 12/13/2021-12/19/2021	N	Jean-Luc Picard
#
# SPL			Check	12/20/2021	Payroll Expenses:Wages	423.08	Gross Pay - This is not a legal pay stub
#
# SPL			Check	12/20/2021	Payroll Expenses:Taxes	50.62	Employer Taxes
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Local Tax	-29.23	MO Local Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Unemployment Tax	0.00	MO Unemployment Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:Federal Unemployment (940)	0.00	Federal Unemployment (940)
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Income Tax	-43.00	MO Income Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:Federal Taxes (941/944)	-269.14	Federal Taxes (941/944)
#
# ENDTRNS

# %%
with open("iif_test.iif") as file:
    data = file.read()

# %%
regex = r"\tN\t(.+)\t\n"
print(re.findall(regex, data))
# Out:
# ['Jean-Luc Picard', 'William Riker', 'Geordi La Forge', 'Tasha Yar', 'Worf', 'Beverly Crusher', 'Lwaxana Troi', 'Q', 'The Traveler', 'Jean-Luc Picard', 'William Riker', 'Tasha Yar', 'Worf', 'Q', 'Beverly Crusher', 'Q', 'Lwaxana Troi', 'Geordi La Forge', 'Wesley Crusher', 'The Traveler', 'MO Division of Employment Security', 'IRS', 'MO Department of Revenue', 'IRS', 'IRS', 'IRS', 'MO Department of Revenue', 'IRS', 'IRS', 'IRS', 'IRS', 'IRS', 'MO Department of Revenue', 'IRS', 'IRS', 'IRS', 'IRS', 'MO Division of Employment Security', 'MO Department of Revenue', 'IRS']

# %%
def iif_to_df(file):
''' Takes a string file path/name of an iif format file as input and returns a pandas DataFrame object.
    Requires re, numpy as np, and pandas as pd imports.
    Not a generalized function. Only scrapes for specific regional taxes: Saint Louis, Missouri, US'''
    
    #Make sure dependencies are installed:
    try:
        test = re.findall("t", "test")
    except NameError:
        return "re package not found. Please import it first."
    try:
        test = np.nan
    except NameError:
        return "numpy package not found. Please import it as np."
    try:
        test = pd.DataFrame()
    except NameError:
        return "pandas package not found. Please import it as pd."


    # Read in data
    with open(file) as f:
        data = f.read()
    data = data.split("\nTRNS")

    # Create Regular Expression search terms
    regex_Name = r"\tN\t(.+)\t\n"
    regex_Pay_Period = r"\d+/\d+/\d+-\d+/\d+/\d+"
    regex_Gross_Pay = r"Expenses:Wages\t(\d+\.\d\d)\tGross Pay"
    regex_Employer_Taxes = r"Expenses:Taxes\t(-?\d+\.\d\d)\tEmployer Taxes\t\n"
    regex_MO_Local_Tax = r"Liabilities:MO Local Tax\t(-?\d+\.\d\d)\tMO Local Tax\t\n"
    regex_MO_Unemployment_Tax = r"Payroll Liabilities:MO Unemployment Tax\t(-?\d+\.\d\d)\tMO Unemployment Tax\t\n"
    regex_Federal_Unemployment = r"Payroll Liabilities:Federal Unemployment \(940\)\t(-?\d+\.\d\d)\tFederal Unemployment \(940\)\t\n"
    regex_MO_Income_Tax = "Payroll Liabilities:MO Income Tax\t(-?\d+\.\d\d)\tMO Income Tax\t\n"
    regex_Federal_Taxes = r"Payroll Liabilities:Federal Taxes \(941/944\)\t(-?\d+\.\d\d)\tFederal Taxes \(941/944\)\t\n"

    # A list values that will be float type.
    employee_line_items = [regex_Gross_Pay, regex_Employer_Taxes, regex_MO_Local_Tax, regex_MO_Unemployment_Tax, 
                           regex_Federal_Unemployment, regex_MO_Income_Tax, regex_Federal_Taxes]

    # Empty lists for our column values.
    Name = []
    Pay_Start = []
    Pay_End = []
    Gross_Pay = [] 
    Employer_Taxes = [] 
    MO_Local_Tax = []
    MO_Unemployment_Tax = []
    Federal_Unemployment = []
    MO_Income_Tax = []
    Federal_Taxes = []

    # A list of column names for creating our DataFrame.
    keys = ["Name", "Pay_Start", "Pay_End", "Gross_Pay", "Employer_Taxes", "MO_Local_Tax", 
               "MO_Unemployment_Tax", "Federal_Unemployment", "MO_Income_Tax", "Federal_Taxes"]

    # A list of empty lists to loop through and append.
    buckets = [Name, Pay_Start, Pay_End, Gross_Pay, Employer_Taxes, MO_Local_Tax, 
               MO_Unemployment_Tax, Federal_Unemployment, MO_Income_Tax, Federal_Taxes]

    for i in range(1,len(data)):
        name_ = re.findall(regex_Name, data[i])[0]
        Name.append(name_)

        # Scrapes the pay range info and splits it into start and end buckets.
        pay_period_ = str(re.findall(regex_Pay_Period, data[i])[0])
        start_end = pay_period_.split("-")
        Pay_Start.append(start_end[0])
        Pay_End.append(start_end[1])

        #We've filled the first 3 buckets. Create an index variable starting at 3 and loop through the rest.
        buckets_index = 3
        for item in employee_line_items:
            try:
                value = float(re.findall(item, data[i])[0])
                buckets[buckets_index].append(value)
                buckets_index += 1
            except IndexError:
                buckets[buckets_index].append(np.nan)
                buckets_index += 1
    
    # Create an empty dictionary to prep for our DataFrame, fill it, and create the DataFrame:
    iif_dict = {}
    for key, bucket in zip(keys, buckets):
        iif_dict[key] = bucket
    temp_df = pd.DataFrame(iif_dict)
    
    # Cast our date columns as DateTime64 objects for ease of analysis.
    temp_df["Pay_Start"] = pd.to_datetime(temp_df["Pay_Start"])
    temp_df["Pay_End"] = pd.to_datetime(temp_df["Pay_End"])

    return temp_df

# %%
iif_to_df("iif_test.iif").describe()
# Out:
#         Gross_Pay  Employer_Taxes  MO_Local_Tax  MO_Unemployment_Tax  \
# count   20.000000       20.000000     18.000000            22.000000
# mean   584.542500       37.785000     -7.086667           872.877273
# std    298.199266       23.244213      7.178045          2834.454080
# min     34.000000        6.510000    -29.230000           -31.520000
# 25%    373.237500       21.592500     -7.867500            -2.015000
# 50%    680.465000       32.415000     -5.740000            -0.615000
# 75%    839.830000       57.165000     -3.445000             0.000000
# max    935.400000       78.850000      0.000000          9780.850000
#
#        Federal_Unemployment  MO_Income_Tax  Federal_Taxes
# count             22.000000      24.000000      32.000000
# mean             860.927727    1579.291667    2161.490000
# std             2790.817259    3642.538717    3856.117553
# min               -4.830000     -43.000000    -273.230000
# 25%               -1.687500     -22.500000    -135.477500
# 50%                0.000000      -6.500000     -36.615000
# 75%                0.000000       0.000000    1359.555000
# max             9718.780000    9819.000000    9461.900000

# %%
# Out:
#               Name  Pay_Start    Pay_End  Gross_Pay  Employer_Taxes  \
# 0  Jean-Luc Picard 2021-12-13 2021-12-19     423.08           50.62
# 1    William Riker 2021-12-13 2021-12-19     917.60           62.55
# 2  Geordi La Forge 2021-12-13 2021-12-19     686.93           25.19
# 3        Tasha Yar 2021-12-13 2021-12-19     316.50           22.24
# 4             Worf 2021-12-13 2021-12-19      67.45            7.67
#
#    MO_Local_Tax  MO_Unemployment_Tax  Federal_Unemployment  MO_Income_Tax  \
# 0        -29.23                 0.00                  0.00          -43.0
# 1           NaN                 0.00                  0.00          -38.0
# 2        -12.87               -31.52                 -1.72           -1.0
# 3         -5.17                -2.73                  0.00          -11.0
# 4         -0.87                -0.46                 -0.52            0.0
#
#    Federal_Taxes  Month  Day
# 0        -269.14     12   13
# 1        -190.42     12   13
# 2         -88.46     12   13
# 3        -128.21     12   13
# 4         -13.38     12   13

# %%
for i in range(260):
    print(data_list[i])
# Out:
# !ACCNT	NAME	ACCNTTYPE	DESC
#
# !CLASS	NAME
#
#
#
# !TRNS	TRNSID	DOCNUM	TRNSTYPE	DATE	ACCNT	AMOUNT	MEMO	TOPRINT	NAME	CLASS
#
# !SPL	SPLID	DOCNUM	TRNSTYPE	DATE	ACCNT	AMOUNT	MEMO	CLASS
#
# !ENDTRNS
#
#
#
# ACCNT	Payroll Expenses:Wages	EXP	Wage Account - Employee Gross Pay
#
# ACCNT	Business Checking	BANK	Checking Account - Payroll
#
# ACCNT	Payroll Liabilities:MO Income Tax	OCLIAB	Payee Account - Total Taxes
#
# ACCNT	Payroll Liabilities:MO Local Tax	OCLIAB	Payee Account - Total Taxes
#
# ACCNT	Payroll Liabilities:Federal Unemployment (940)	OCLIAB	Payee Account - Total Taxes
#
# ACCNT	Payroll Liabilities:Federal Taxes (941/944)	OCLIAB	Payee Account - Total Taxes
#
# ACCNT	Payroll Liabilities:MO Unemployment Tax	OCLIAB	Payee Account - Total Taxes
#
# ACCNT	Payroll Expenses:Taxes	EXP	Tax Account - Employer Taxes
#
# TRNS			Check	12/20/2021	Business Checking	-722.33	Pay Period: 12/13/2021-12/19/2021	N	Michael S. Black
#
# SPL			Check	12/20/2021	Payroll Expenses:Wages	923.08	Gross Pay - This is not a legal pay stub
#
# SPL			Check	12/20/2021	Payroll Expenses:Taxes	70.62	Employer Taxes
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Local Tax	-9.23	MO Local Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Unemployment Tax	0.00	MO Unemployment Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:Federal Unemployment (940)	0.00	Federal Unemployment (940)
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Income Tax	-33.00	MO Income Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:Federal Taxes (941/944)	-229.14	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/20/2021	Business Checking	-661.73	Pay Period: 12/13/2021-12/19/2021	N	Rachel Browner
#
# SPL			Check	12/20/2021	Payroll Expenses:Wages	817.60	Gross Pay - This is not a legal pay stub
#
# SPL			Check	12/20/2021	Payroll Expenses:Taxes	62.55	Employer Taxes
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Unemployment Tax	0.00	MO Unemployment Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:Federal Unemployment (940)	0.00	Federal Unemployment (940)
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Income Tax	-28.00	MO Income Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:Federal Taxes (941/944)	-190.42	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/20/2021	Business Checking	-256.55	Pay Period: 12/13/2021-12/19/2021	N	Hallin A. Burgan
#
# SPL			Check	12/20/2021	Payroll Expenses:Wages	286.93	Gross Pay - This is not a legal pay stub
#
# SPL			Check	12/20/2021	Payroll Expenses:Taxes	25.19	Employer Taxes
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Local Tax	-2.87	MO Local Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Unemployment Tax	-1.52	MO Unemployment Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:Federal Unemployment (940)	-1.72	Federal Unemployment (940)
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Income Tax	-1.00	MO Income Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:Federal Taxes (941/944)	-48.46	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/20/2021	Business Checking	-431.63	Pay Period: 12/13/2021-12/19/2021	N	Shelbey Easley
#
# SPL			Check	12/20/2021	Payroll Expenses:Wages	516.50	Gross Pay - This is not a legal pay stub
#
# SPL			Check	12/20/2021	Payroll Expenses:Taxes	42.24	Employer Taxes
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Local Tax	-5.17	MO Local Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Unemployment Tax	-2.73	MO Unemployment Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:Federal Unemployment (940)	0.00	Federal Unemployment (940)
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Income Tax	-11.00	MO Income Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:Federal Taxes (941/944)	-108.21	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/20/2021	Business Checking	-79.89	Pay Period: 12/13/2021-12/19/2021	N	Gabriel Grabarek
#
# SPL			Check	12/20/2021	Payroll Expenses:Wages	87.45	Gross Pay - This is not a legal pay stub
#
# SPL			Check	12/20/2021	Payroll Expenses:Taxes	7.67	Employer Taxes
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Local Tax	-0.87	MO Local Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Unemployment Tax	-0.46	MO Unemployment Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:Federal Unemployment (940)	-0.52	Federal Unemployment (940)
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Income Tax	0.00	MO Income Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:Federal Taxes (941/944)	-13.38	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/20/2021	Business Checking	-644.62	Pay Period: 12/13/2021-12/19/2021	N	John T. Key
#
# SPL			Check	12/20/2021	Payroll Expenses:Wages	805.08	Gross Pay - This is not a legal pay stub
#
# SPL			Check	12/20/2021	Payroll Expenses:Taxes	70.67	Employer Taxes
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Local Tax	-8.05	MO Local Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Unemployment Tax	-4.25	MO Unemployment Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:Federal Unemployment (940)	-4.83	Federal Unemployment (940)
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Income Tax	-27.00	MO Income Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:Federal Taxes (941/944)	-187.00	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/20/2021	Business Checking	-516.24	Pay Period: 12/13/2021-12/19/2021	N	Abigail C. Kopp
#
# SPL			Check	12/20/2021	Payroll Expenses:Wages	630.70	Gross Pay - This is not a legal pay stub
#
# SPL			Check	12/20/2021	Payroll Expenses:Taxes	55.37	Employer Taxes
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Local Tax	-6.31	MO Local Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Unemployment Tax	-3.33	MO Unemployment Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:Federal Unemployment (940)	-3.79	Federal Unemployment (940)
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Income Tax	-17.00	MO Income Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:Federal Taxes (941/944)	-139.40	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/20/2021	Business Checking	-527.75	Pay Period: 12/13/2021-12/19/2021	N	Carli A. Littlejohn
#
# SPL			Check	12/20/2021	Payroll Expenses:Wages	674.00	Gross Pay - This is not a legal pay stub
#
# SPL			Check	12/20/2021	Payroll Expenses:Taxes	51.57	Employer Taxes
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Local Tax	-6.74	MO Local Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Unemployment Tax	0.00	MO Unemployment Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:Federal Unemployment (940)	0.00	Federal Unemployment (940)
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Income Tax	-20.00	MO Income Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:Federal Taxes (941/944)	-171.08	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/20/2021	Business Checking	-298.33	Pay Period: 12/13/2021-12/19/2021	N	Monica Tirre
#
# SPL			Check	12/20/2021	Payroll Expenses:Wages	335.40	Gross Pay - This is not a legal pay stub
#
# SPL			Check	12/20/2021	Payroll Expenses:Taxes	27.43	Employer Taxes
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Local Tax	0.00	MO Local Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Unemployment Tax	-1.77	MO Unemployment Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:Federal Unemployment (940)	0.00	Federal Unemployment (940)
#
# SPL			Check	12/20/2021	Payroll Liabilities:MO Income Tax	-2.00	MO Income Tax
#
# SPL			Check	12/20/2021	Payroll Liabilities:Federal Taxes (941/944)	-60.73	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/27/2021	Business Checking	-733.23	Pay Period: 12/20/2021-12/26/2021	N	Michael S. Black
#
# SPL			Check	12/27/2021	Payroll Expenses:Wages	938.08	Gross Pay - This is not a legal pay stub
#
# SPL			Check	12/27/2021	Payroll Expenses:Taxes	71.76	Employer Taxes
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Local Tax	-9.38	MO Local Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Unemployment Tax	0.00	MO Unemployment Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:Federal Unemployment (940)	0.00	Federal Unemployment (940)
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Income Tax	-34.00	MO Income Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:Federal Taxes (941/944)	-233.23	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/27/2021	Business Checking	-586.10	Pay Period: 12/20/2021-12/26/2021	N	Rachel Browner
#
# SPL			Check	12/27/2021	Payroll Expenses:Wages	716.00	Gross Pay - This is not a legal pay stub
#
# SPL			Check	12/27/2021	Payroll Expenses:Taxes	54.77	Employer Taxes
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Unemployment Tax	0.00	MO Unemployment Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:Federal Unemployment (940)	0.00	Federal Unemployment (940)
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Income Tax	-22.00	MO Income Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:Federal Taxes (941/944)	-162.67	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/27/2021	Business Checking	-67.59	Pay Period: 12/20/2021-12/26/2021	N	Hallin A. Burgan
#
# SPL			Check	12/27/2021	Payroll Expenses:Wages	74.00	Gross Pay - This is not a legal pay stub
#
# SPL			Check	12/27/2021	Payroll Expenses:Taxes	6.51	Employer Taxes
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Local Tax	-0.74	MO Local Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Unemployment Tax	-0.39	MO Unemployment Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:Federal Unemployment (940)	-0.45	Federal Unemployment (940)
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Income Tax	0.00	MO Income Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:Federal Taxes (941/944)	-11.34	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/27/2021	Business Checking	-307.15	Pay Period: 12/20/2021-12/26/2021	N	Shelbey Easley
#
# SPL			Check	12/27/2021	Payroll Expenses:Wages	351.60	Gross Pay - This is not a legal pay stub
#
# SPL			Check	12/27/2021	Payroll Expenses:Taxes	28.75	Employer Taxes
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Local Tax	-3.52	MO Local Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Unemployment Tax	-1.85	MO Unemployment Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:Federal Unemployment (940)	0.00	Federal Unemployment (940)
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Income Tax	-3.00	MO Income Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:Federal Taxes (941/944)	-64.83	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/27/2021	Business Checking	-299.64	Pay Period: 12/20/2021-12/26/2021	N	Gabriel Grabarek
#
# SPL			Check	12/27/2021	Payroll Expenses:Wages	342.35	Gross Pay - This is not a legal pay stub
#
# SPL			Check	12/27/2021	Payroll Expenses:Taxes	30.06	Employer Taxes
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Local Tax	-3.42	MO Local Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Unemployment Tax	-1.81	MO Unemployment Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:Federal Unemployment (940)	-2.06	Federal Unemployment (940)
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Income Tax	-3.00	MO Income Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:Federal Taxes (941/944)	-62.48	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/27/2021	Business Checking	-606.35	Pay Period: 12/20/2021-12/26/2021	N	John T. Key
#
# SPL			Check	12/27/2021	Payroll Expenses:Wages	753.08	Gross Pay - This is not a legal pay stub
#
# SPL			Check	12/27/2021	Payroll Expenses:Taxes	63.19	Employer Taxes
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Local Tax	-7.53	MO Local Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Unemployment Tax	-3.98	MO Unemployment Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:Federal Unemployment (940)	-1.59	Federal Unemployment (940)
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Income Tax	-24.00	MO Income Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:Federal Taxes (941/944)	-172.82	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/27/2021	Business Checking	-338.63	Pay Period: 12/20/2021-12/26/2021	N	Abigail C. Kopp
#
# SPL			Check	12/27/2021	Payroll Expenses:Wages	392.75	Gross Pay - This is not a legal pay stub
#
# SPL			Check	12/27/2021	Payroll Expenses:Taxes	34.47	Employer Taxes
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Local Tax	-3.93	MO Local Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Unemployment Tax	-2.07	MO Unemployment Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:Federal Unemployment (940)	-2.35	Federal Unemployment (940)
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Income Tax	-5.00	MO Income Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:Federal Taxes (941/944)	-75.24	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/27/2021	Business Checking	-557.10	Pay Period: 12/20/2021-12/26/2021	N	Carli A. Littlejohn
#
# SPL			Check	12/27/2021	Payroll Expenses:Wages	713.50	Gross Pay - This is not a legal pay stub
#
# SPL			Check	12/27/2021	Payroll Expenses:Taxes	54.58	Employer Taxes
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Local Tax	-7.14	MO Local Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Unemployment Tax	0.00	MO Unemployment Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:Federal Unemployment (940)	0.00	Federal Unemployment (940)
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Income Tax	-22.00	MO Income Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:Federal Taxes (941/944)	-181.84	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/27/2021	Business Checking	-154.23	Pay Period: 12/20/2021-12/26/2021	N	Monica Tirre
#
# SPL			Check	12/27/2021	Payroll Expenses:Wages	167.00	Gross Pay - This is not a legal pay stub
#
# SPL			Check	12/27/2021	Payroll Expenses:Taxes	13.65	Employer Taxes
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Local Tax	0.00	MO Local Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Unemployment Tax	-0.88	MO Unemployment Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:Federal Unemployment (940)	0.00	Federal Unemployment (940)
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Income Tax	0.00	MO Income Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:Federal Taxes (941/944)	-25.54	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/27/2021	Business Checking	-417.62	Pay Period: 12/20/2021-12/26/2021	N	David J. Varwig
#
# SPL			Check	12/27/2021	Payroll Expenses:Wages	497.60	Gross Pay - This is not a legal pay stub
#
# SPL			Check	12/27/2021	Payroll Expenses:Taxes	38.85	Employer Taxes
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Local Tax	-4.98	MO Local Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Unemployment Tax	-0.77	MO Unemployment Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:Federal Unemployment (940)	0.00	Federal Unemployment (940)
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Income Tax	-10.00	MO Income Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:Federal Taxes (941/944)	-103.08	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/27/2021	Business Checking	-248.53	Pay Period: 12/20/2021-12/26/2021	N	Hayley Young
#
# SPL			Check	12/27/2021	Payroll Expenses:Wages	298.15	Gross Pay - This is not a legal pay stub
#
# SPL			Check	12/27/2021	Payroll Expenses:Taxes	22.80	Employer Taxes
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Local Tax	-2.98	MO Local Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Unemployment Tax	0.00	MO Unemployment Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:Federal Unemployment (940)	0.00	Federal Unemployment (940)
#
# SPL			Check	12/27/2021	Payroll Liabilities:MO Income Tax	-1.00	MO Income Tax
#
# SPL			Check	12/27/2021	Payroll Liabilities:Federal Taxes (941/944)	-68.44	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	11/01/2021	Business Checking	-160.85	Tax Payment for Period: 07/01/2021-09/30/2021	N	MO Division of Employment Security
#
# SPL			Check	11/01/2021	Payroll Liabilities:MO Unemployment Tax	160.85	MO Unemployment Tax
#
# SPL			Check	11/01/2021	Payroll Liabilities:MO Unemployment Tax	-0.01	MO Unemployment Tax
#
# SPL			Check	11/01/2021	Payroll Expenses:Taxes	0.01	MO Unemployment Tax
#
# ENDTRNS
#
# TRNS			Check	10/14/2021	Business Checking	-1334.30	Tax Payment for Period: 10/06/2021-10/08/2021	N	IRS
#
# SPL			Check	10/14/2021	Payroll Liabilities:Federal Taxes (941/944)	1334.30	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	10/20/2021	Business Checking	-544.00	Tax Payment for Period: 09/01/2021-09/30/2021	N	MO Department of Revenue
#
# SPL			Check	10/20/2021	Payroll Liabilities:MO Income Tax	544.00	MO Income Tax
#
# SPL			Check	10/20/2021	Payroll Liabilities:MO Income Tax	11.00	MO Income Tax
#
# SPL			Check	10/20/2021	Payroll Expenses:Taxes	-11.00	MO Income Tax
#
# ENDTRNS
#
# TRNS			Check	10/20/2021	Business Checking	-518.78	Tax Payment for Period: 01/01/2021-09/30/2021	N	IRS
#
# SPL			Check	10/20/2021	Payroll Liabilities:Federal Unemployment (940)	518.78	Federal Unemployment (940)
#
# ENDTRNS
#
# TRNS			Check	10/22/2021	Business Checking	-1278.29	Tax Payment for Period: 10/16/2021-10/19/2021	N	IRS
#
# SPL			Check	10/22/2021	Payroll Liabilities:Federal Taxes (941/944)	1278.29	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	10/29/2021	Business Checking	-1465.90	Tax Payment for Period: 10/23/2021-10/26/2021	N	IRS
#
# SPL			Check	10/29/2021	Payroll Liabilities:Federal Taxes (941/944)	1465.90	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	11/08/2021	Business Checking	-621.00	Tax Payment for Period: 10/01/2021-10/31/2021	N	MO Department of Revenue
#
# SPL			Check	11/08/2021	Payroll Liabilities:MO Income Tax	621.00	MO Income Tax
#
# SPL			Check	11/08/2021	Payroll Liabilities:MO Income Tax	6.00	MO Income Tax
#
# SPL			Check	11/08/2021	Payroll Expenses:Taxes	-6.00	MO Income Tax
#
# ENDTRNS
#
# TRNS			Check	11/05/2021	Business Checking	-1415.61	Tax Payment for Period: 10/30/2021-11/02/2021	N	IRS
#
# SPL			Check	11/05/2021	Payroll Liabilities:Federal Taxes (941/944)	1415.61	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	11/15/2021	Business Checking	-1608.60	Tax Payment for Period: 11/06/2021-11/09/2021	N	IRS
#
# SPL			Check	11/15/2021	Payroll Liabilities:Federal Taxes (941/944)	1608.60	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	11/19/2021	Business Checking	-1464.11	Tax Payment for Period: 11/13/2021-11/16/2021	N	IRS
#
# SPL			Check	11/19/2021	Payroll Liabilities:Federal Taxes (941/944)	1464.11	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	11/29/2021	Business Checking	-1488.02	Tax Payment for Period: 11/20/2021-11/23/2021	N	IRS
#
# SPL			Check	11/29/2021	Payroll Liabilities:Federal Taxes (941/944)	1488.02	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/03/2021	Business Checking	-1012.12	Tax Payment for Period: 11/27/2021-11/30/2021	N	IRS
#
# SPL			Check	12/03/2021	Payroll Liabilities:Federal Taxes (941/944)	1012.12	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/08/2021	Business Checking	-819.00	Tax Payment for Period: 11/01/2021-11/30/2021	N	MO Department of Revenue
#
# SPL			Check	12/08/2021	Payroll Liabilities:MO Income Tax	819.00	MO Income Tax
#
# SPL			Check	12/08/2021	Payroll Liabilities:MO Income Tax	8.00	MO Income Tax
#
# SPL			Check	12/08/2021	Payroll Expenses:Taxes	-8.00	MO Income Tax
#
# ENDTRNS
#
# TRNS			Check	12/10/2021	Business Checking	-1395.57	Tax Payment for Period: 12/04/2021-12/07/2021	N	IRS
#
# SPL			Check	12/10/2021	Payroll Liabilities:Federal Taxes (941/944)	1395.57	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/17/2021	Business Checking	-1347.55	Tax Payment for Period: 12/11/2021-12/14/2021	N	IRS
#
# SPL			Check	12/17/2021	Payroll Liabilities:Federal Taxes (941/944)	1347.55	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/24/2021	Business Checking	-1330.43	Tax Payment for Period: 12/18/2021-12/21/2021	N	IRS
#
# SPL			Check	12/24/2021	Payroll Liabilities:Federal Taxes (941/944)	1330.43	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	12/31/2021	Business Checking	-1161.51	Tax Payment for Period: 12/25/2021-12/28/2021	N	IRS
#
# SPL			Check	12/31/2021	Payroll Liabilities:Federal Taxes (941/944)	1161.51	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	01/31/2022	Business Checking	-176.96	Tax Payment for Period: 10/01/2021-12/31/2021	N	MO Division of Employment Security
#
# SPL			Check	01/31/2022	Payroll Liabilities:MO Unemployment Tax	176.96	MO Unemployment Tax
#
# ENDTRNS
#
# TRNS			Check	01/19/2022	Business Checking	-614.00	Tax Payment for Period: 12/01/2021-12/31/2021	N	MO Department of Revenue
#
# SPL			Check	01/19/2022	Payroll Liabilities:MO Income Tax	614.00	MO Income Tax
#
# SPL			Check	01/19/2022	Payroll Liabilities:MO Income Tax	6.00	MO Income Tax
#
# SPL			Check	01/19/2022	Payroll Expenses:Taxes	-6.00	MO Income Tax
#
# ENDTRNS

# %%
print(MO_Local_Tax)
# Out:
# [-9.23, nan, -2.87, -5.17, -0.87, -8.05, -6.31, -6.74, 0.0, -9.38, nan, -0.74, -3.52, -3.42, -7.53, -3.93, -7.14, 0.0, -4.98, -2.98, nan, nan, nan, nan, nan, nan, nan, nan, nan]

# %%
string = "12/31/2021-12/32/2021"

# %%
# Out:
# 12/31/2021
