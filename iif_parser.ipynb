# %%
import re
import pandas as pd
import numpy as np
import os
import missingno as msno

# %%
with open("./merge/payroll_2016.iif") as file:
    data_list = file.readlines()

# %%
# Examine the raw file to figure out the best way to break it down
print(f">>>This iif file contains {len(data_list)} lines<<<\n")
for i in range(0, 30):
    print(repr(data_list[i]))
# Out:
# >>>This iif file contains 2897 lines<<<
#
# '!ACCNT\tNAME\tACCNTTYPE\tDESC\n'
# '!CLASS\tNAME\n'
# '\n'
# '!TRNS\tTRNSID\tDOCNUM\tTRNSTYPE\tDATE\tACCNT\tAMOUNT\tMEMO\tTOPRINT\tNAME\tCLASS\n'
# '!SPL\tSPLID\tDOCNUM\tTRNSTYPE\tDATE\tACCNT\tAMOUNT\tMEMO\tCLASS\n'
# '!ENDTRNS\n'
# '\n'
# 'ACCNT\tPayroll Expenses:Wages\tEXP\tWage Account - Employee Gross Pay\n'
# 'ACCNT\tBusiness Checking\tBANK\tChecking Account - Payroll\n'
# 'ACCNT\tPayroll Liabilities:MO Income Tax\tOCLIAB\tPayee Account - Total Taxes\n'
# 'ACCNT\tPayroll Liabilities:Aflac\tOCLIAB\tPayee Account - Employee Deductions\n'
# 'ACCNT\tPayroll Liabilities:MO Local Tax\tOCLIAB\tPayee Account - Total Taxes\n'
# 'ACCNT\tPayroll Liabilities:Federal Unemployment (940)\tOCLIAB\tPayee Account - Total Taxes\n'
# 'ACCNT\tPayroll Liabilities:Federal Taxes (941/944)\tOCLIAB\tPayee Account - Total Taxes\n'
# 'ACCNT\tPayroll Liabilities:MO Unemployment Tax\tOCLIAB\tPayee Account - Total Taxes\n'
# 'ACCNT\tPayroll Expenses:Taxes\tEXP\tTax Account - Employer Taxes\n'
# 'TRNS\t\t\tCheck\t01/17/2016\tBusiness Checking\t-546.28\tPay Period: 12/31/2015-01/15/2016\tN\tMark H. Attwood\t\n'
# 'SPL\t\t\tCheck\t01/17/2016\tPayroll Expenses:Wages\t687.50\tGross Pay - This is not a legal pay stub\t\n'
# 'SPL\t\t\tCheck\t01/17/2016\tPayroll Expenses:Taxes\t52.60\tEmployer Taxes\t\n'
# 'SPL\t\t\tCheck\t01/17/2016\tPayroll Liabilities:MO Local Tax\t-6.88\tMO Local Tax\t\n'
# 'SPL\t\t\tCheck\t01/17/2016\tPayroll Liabilities:MO Income Tax\t-12.00\tMO Income Tax\t\n'
# 'SPL\t\t\tCheck\t01/17/2016\tPayroll Liabilities:Federal Taxes (941/944)\t-174.94\tFederal Taxes (941/944)\t\n'
# 'ENDTRNS\n'
# 'TRNS\t\t\tCheck\t01/17/2016\tBusiness Checking\t-546.28\tPay Period: 12/31/2015-01/15/2016\tN\tStephanie D. Attwood\t\n'
# 'SPL\t\t\tCheck\t01/17/2016\tPayroll Expenses:Wages\t687.50\tGross Pay - This is not a legal pay stub\t\n'
# 'SPL\t\t\tCheck\t01/17/2016\tPayroll Expenses:Taxes\t52.60\tEmployer Taxes\t\n'
# 'SPL\t\t\tCheck\t01/17/2016\tPayroll Liabilities:MO Local Tax\t-6.88\tMO Local Tax\t\n'
# 'SPL\t\t\tCheck\t01/17/2016\tPayroll Liabilities:MO Income Tax\t-12.00\tMO Income Tax\t\n'
# 'SPL\t\t\tCheck\t01/17/2016\tPayroll Liabilities:Federal Taxes (941/944)\t-174.94\tFederal Taxes (941/944)\t\n'
# 'ENDTRNS\n'

# %%
# An individual record, starts at 'TRNS', ends at 'ENDTRNS'
for i in range(15,100):
    print(data_list[i])
# Out:
# ACCNT	Payroll Expenses:Taxes	EXP	Tax Account - Employer Taxes
#
# TRNS			Check	01/17/2016	Business Checking	-546.28	Pay Period: 12/31/2015-01/15/2016	N	Mark H. Attwood
#
# SPL			Check	01/17/2016	Payroll Expenses:Wages	687.50	Gross Pay - This is not a legal pay stub
#
# SPL			Check	01/17/2016	Payroll Expenses:Taxes	52.60	Employer Taxes
#
# SPL			Check	01/17/2016	Payroll Liabilities:MO Local Tax	-6.88	MO Local Tax
#
# SPL			Check	01/17/2016	Payroll Liabilities:MO Income Tax	-12.00	MO Income Tax
#
# SPL			Check	01/17/2016	Payroll Liabilities:Federal Taxes (941/944)	-174.94	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	01/17/2016	Business Checking	-546.28	Pay Period: 12/31/2015-01/15/2016	N	Stephanie D. Attwood
#
# SPL			Check	01/17/2016	Payroll Expenses:Wages	687.50	Gross Pay - This is not a legal pay stub
#
# SPL			Check	01/17/2016	Payroll Expenses:Taxes	52.60	Employer Taxes
#
# SPL			Check	01/17/2016	Payroll Liabilities:MO Local Tax	-6.88	MO Local Tax
#
# SPL			Check	01/17/2016	Payroll Liabilities:MO Income Tax	-12.00	MO Income Tax
#
# SPL			Check	01/17/2016	Payroll Liabilities:Federal Taxes (941/944)	-174.94	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			GENERAL JOURNAL	01/17/2016	Payroll Expenses:Taxes	-5.69	Employer Taxes	N	Julie R. Brown
#
# SPL			GENERAL JOURNAL	01/17/2016	Payroll Liabilities:MO Unemployment Tax	5.69	MO Unemployment Tax
#
# ENDTRNS
#
# TRNS			Check	01/17/2016	Business Checking	-412.23	Pay Period: 12/31/2015-01/15/2016	N	Julie R. Brown
#
# SPL			Check	01/17/2016	Payroll Expenses:Wages	501.20	Gross Pay - This is not a legal pay stub
#
# SPL			Check	01/17/2016	Payroll Expenses:Taxes	54.71	Employer Taxes
#
# SPL			Check	01/17/2016	Payroll Liabilities:Aflac	-14.43	Aflac
#
# SPL			Check	01/17/2016	Payroll Liabilities:MO Local Tax	-4.87	MO Local Tax
#
# SPL			Check	01/17/2016	Payroll Liabilities:MO Unemployment Tax	-14.55	MO Unemployment Tax
#
# SPL			Check	01/17/2016	Payroll Liabilities:Federal Unemployment (940)	-2.92	Federal Unemployment (940)
#
# SPL			Check	01/17/2016	Payroll Liabilities:MO Income Tax	-10.00	MO Income Tax
#
# SPL			Check	01/17/2016	Payroll Liabilities:Federal Taxes (941/944)	-96.91	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			Check	01/17/2016	Business Checking	-828.87	Pay Period: 12/31/2015-01/15/2016	N	Michael F. Butler
#
# SPL			Check	01/17/2016	Payroll Expenses:Wages	1072.00	Gross Pay - This is not a legal pay stub
#
# SPL			Check	01/17/2016	Payroll Expenses:Taxes	120.48	Employer Taxes
#
# SPL			Check	01/17/2016	Payroll Liabilities:MO Local Tax	-10.72	MO Local Tax
#
# SPL			Check	01/17/2016	Payroll Liabilities:MO Unemployment Tax	-32.05	MO Unemployment Tax
#
# SPL			Check	01/17/2016	Payroll Liabilities:Federal Unemployment (940)	-6.43	Federal Unemployment (940)
#
# SPL			Check	01/17/2016	Payroll Liabilities:MO Income Tax	-23.00	MO Income Tax
#
# SPL			Check	01/17/2016	Payroll Liabilities:Federal Taxes (941/944)	-291.41	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			GENERAL JOURNAL	01/17/2016	Payroll Expenses:Taxes	-12.54	Employer Taxes	N	Michael F. Butler
#
# SPL			GENERAL JOURNAL	01/17/2016	Payroll Liabilities:MO Unemployment Tax	12.54	MO Unemployment Tax
#
# ENDTRNS
#
# TRNS			Check	01/17/2016	Business Checking	-798.70	Pay Period: 12/31/2015-01/15/2016	N	Megan K. Cronin
#
# SPL			Check	01/17/2016	Payroll Expenses:Wages	1041.67	Gross Pay - This is not a legal pay stub
#
# SPL			Check	01/17/2016	Payroll Expenses:Taxes	117.08	Employer Taxes
#
# SPL			Check	01/17/2016	Payroll Liabilities:MO Local Tax	-10.42	MO Local Tax
#
# SPL			Check	01/17/2016	Payroll Liabilities:MO Unemployment Tax	-31.15	MO Unemployment Tax
#
# SPL			Check	01/17/2016	Payroll Liabilities:Federal Unemployment (940)	-6.25	Federal Unemployment (940)
#
# SPL			Check	01/17/2016	Payroll Liabilities:MO Income Tax	-30.00	MO Income Tax
#
# SPL			Check	01/17/2016	Payroll Liabilities:Federal Taxes (941/944)	-282.23	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			GENERAL JOURNAL	01/17/2016	Payroll Expenses:Taxes	-12.19	Employer Taxes	N	Megan K. Cronin
#
# SPL			GENERAL JOURNAL	01/17/2016	Payroll Liabilities:MO Unemployment Tax	12.19	MO Unemployment Tax
#
# ENDTRNS
#
# TRNS			Check	01/17/2016	Business Checking	-272.13	Pay Period: 12/31/2015-01/15/2016	N	Gretchen Haughey
#
# SPL			Check	01/17/2016	Payroll Expenses:Wages	302.25	Gross Pay - This is not a legal pay stub
#
# SPL			Check	01/17/2016	Payroll Expenses:Taxes	33.97	Employer Taxes
#
# SPL			Check	01/17/2016	Payroll Liabilities:MO Local Tax	-3.02	MO Local Tax
#
# SPL			Check	01/17/2016	Payroll Liabilities:MO Unemployment Tax	-9.04	MO Unemployment Tax
#
# SPL			Check	01/17/2016	Payroll Liabilities:Federal Unemployment (940)	-1.81	Federal Unemployment (940)
#
# SPL			Check	01/17/2016	Payroll Liabilities:MO Income Tax	0.00	MO Income Tax
#
# SPL			Check	01/17/2016	Payroll Liabilities:Federal Taxes (941/944)	-50.22	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			GENERAL JOURNAL	01/17/2016	Payroll Expenses:Taxes	-3.54	Employer Taxes	N	Gretchen Haughey
#
# SPL			GENERAL JOURNAL	01/17/2016	Payroll Liabilities:MO Unemployment Tax	3.54	MO Unemployment Tax
#
# ENDTRNS
#
# TRNS			Check	01/17/2016	Business Checking	-995.87	Pay Period: 12/31/2015-01/15/2016	N	Frank A. Ladish
#
# SPL			Check	01/17/2016	Payroll Expenses:Wages	1291.67	Gross Pay - This is not a legal pay stub
#
# SPL			Check	01/17/2016	Payroll Expenses:Taxes	143.56	Employer Taxes
#
# SPL			Check	01/17/2016	Payroll Liabilities:Aflac	-14.43	Aflac
#
# SPL			Check	01/17/2016	Payroll Liabilities:MO Local Tax	-12.77	MO Local Tax
#
# SPL			Check	01/17/2016	Payroll Liabilities:MO Unemployment Tax	-38.19	MO Unemployment Tax
#
# SPL			Check	01/17/2016	Payroll Liabilities:Federal Unemployment (940)	-7.66	Federal Unemployment (940)
#
# SPL			Check	01/17/2016	Payroll Liabilities:MO Income Tax	-38.00	MO Income Tax
#
# SPL			Check	01/17/2016	Payroll Liabilities:Federal Taxes (941/944)	-328.31	Federal Taxes (941/944)
#
# ENDTRNS
#
# TRNS			GENERAL JOURNAL	01/17/2016	Payroll Expenses:Taxes	-14.94	Employer Taxes	N	Frank A. Ladish
#
# SPL			GENERAL JOURNAL	01/17/2016	Payroll Liabilities:MO Unemployment Tax	14.94	MO Unemployment Tax
#
# ENDTRNS
#
# TRNS			GENERAL JOURNAL	01/17/2016	Payroll Expenses:Taxes	-12.88	Employer Taxes	N	William Paulsen
#
# SPL			GENERAL JOURNAL	01/17/2016	Payroll Liabilities:MO Unemployment Tax	12.88	MO Unemployment Tax
#
# ENDTRNS
#
# TRNS			Check	01/17/2016	Business Checking	-841.01	Pay Period: 12/31/2015-01/15/2016	N	William Paulsen
#
# SPL			Check	01/17/2016	Payroll Expenses:Wages	1101.00	Gross Pay - This is not a legal pay stub
#
# SPL			Check	01/17/2016	Payroll Expenses:Taxes	127.86	Employer Taxes
#
# SPL			Check	01/17/2016	Payroll Liabilities:MO Local Tax	-15.12	MO Local Tax
#
# SPL			Check	01/17/2016	Payroll Liabilities:MO Unemployment Tax	-32.92	MO Unemployment Tax

# %%
# Let's get started!
with open("test_iif.iif") as file:
    data = file.read()

# %%
# Test by extracting the names. We'll have records for the tax payments as well as the payroll payments.
regex = r"\tN\t(.+)\t\n"
print(re.findall(regex, data))
# Out:
# ['Jean-Luc Picard', 'William Riker', 'Geordi La Forge', 'Tasha Yar', 'Worf', 'Beverly Crusher', 'Lwaxana Troi', 'Q', 'The Traveler', 'Jean-Luc Picard', 'William Riker', 'Tasha Yar', 'Worf', 'Q', 'Beverly Crusher', 'Q', 'Lwaxana Troi', 'Geordi La Forge', 'Wesley Crusher', 'The Traveler', 'MO Division of Employment Security', 'IRS', 'MO Department of Revenue', 'IRS', 'IRS', 'IRS', 'MO Department of Revenue', 'IRS', 'IRS', 'IRS', 'IRS', 'IRS', 'MO Department of Revenue', 'IRS', 'IRS', 'IRS', 'IRS', 'MO Division of Employment Security', 'MO Department of Revenue', 'IRS']

# %%
def parse_iif(file):
    ''' Takes a string file path/name of an iif format file as input and returns a pandas DataFrame object.
        Requires re, numpy as np, and pandas as pd imports.
        Not a generalized function. Only scrapes for specific regional taxes: Saint Louis, Missouri, US'''
    
    #Make sure dependencies are installed.
    try:
        test = re.findall("t", "test")
    except NameError:
        return "re package not found. Please import it first."
    try:
        test = np.nan
    except NameError:
        return "numpy package not found. Please import it as np."
    try:
        test = pd.DataFrame()
    except NameError:
        return "pandas package not found. Please import it as pd."


    # Read in the data.
    with open(file) as f:
        data = f.read()
    data = data.split("\nTRNS")

    # Create Regular Expression search terms.
    regex_Name = r"\tN\t(.+)\t\n"
    regex_Pay_Period = r"\d+/\d+/\d+-\d+/\d+/\d+"
    regex_Gross_Pay = r"Expenses:Wages\t(\d+\.\d\d)\tGross Pay"
    regex_Employer_Taxes = r"Expenses:Taxes\t(-?\d+\.\d\d)\tEmployer Taxes\t\n"
    regex_MO_Local_Tax = r"Liabilities:MO Local Tax\t(-?\d+\.\d\d)\tMO Local Tax\t\n"
    regex_MO_Unemployment_Tax = r"Payroll Liabilities:MO Unemployment Tax\t(-?\d+\.\d\d)\tMO Unemployment Tax\t\n"
    regex_Federal_Unemployment = r"Payroll Liabilities:Federal Unemployment \(940\)\t(-?\d+\.\d\d)\tFederal Unemployment \(940\)\t\n"
    regex_MO_Income_Tax = "Payroll Liabilities:MO Income Tax\t(-?\d+\.\d\d)\tMO Income Tax\t\n"
    regex_Federal_Taxes = r"Payroll Liabilities:Federal Taxes \(941/944\)\t(-?\d+\.\d\d)\tFederal Taxes \(941/944\)\t\n"

    # A list of columns that will be float type.
    employee_line_items = [regex_Gross_Pay, regex_Employer_Taxes, regex_MO_Local_Tax, regex_MO_Unemployment_Tax, 
                           regex_Federal_Unemployment, regex_MO_Income_Tax, regex_Federal_Taxes]

    # Create empty lists for our column values.
    Name = []
    Pay_Start = []
    Pay_End = []
    Gross_Pay = [] 
    Employer_Taxes = [] 
    MO_Local_Tax = []
    MO_Unemployment_Tax = []
    Federal_Unemployment = []
    MO_Income_Tax = []
    Federal_Taxes = []

    # A list of column names for creating our DataFrame.
    keys = ["Name", "Pay_Start", "Pay_End", "Gross_Pay", "Employer_Taxes", "MO_Local_Tax", 
               "MO_Unemployment_Tax", "Federal_Unemployment", "MO_Income_Tax", "Federal_Taxes"]

    # A list of empty lists to loop through and append.
    buckets = [Name, Pay_Start, Pay_End, Gross_Pay, Employer_Taxes, MO_Local_Tax, 
               MO_Unemployment_Tax, Federal_Unemployment, MO_Income_Tax, Federal_Taxes]

    for i in range(1,len(data)):
        if "GENERAL JOURNAL" not in data[i]:
            name_ = re.findall(regex_Name, data[i])[0]
            Name.append(name_)

            # Scrapes the pay range info and splits it into start and end buckets.
            try:
                pay_period_ = str(re.findall(regex_Pay_Period, data[i])[0])
                start_end = pay_period_.split("-")
                Pay_Start.append(start_end[0])
                Pay_End.append(start_end[1])
            except IndexError:
                Pay_Start.append(np.nan)
                Pay_End.append(np.nan)

            #We've filled the first 3 buckets. Create an index variable starting at 3 and loop through the rest.
            buckets_index = 3
            for item in employee_line_items:
                try:
                    value = float(re.findall(item, data[i])[0])
                    buckets[buckets_index].append(value)
                    buckets_index += 1
                except IndexError:
                    buckets[buckets_index].append(np.nan)
                    buckets_index += 1

    # Create an empty dictionary to prep for our DataFrame, fill it, and create the DataFrame:
    iif_dict = {}
    for key, bucket in zip(keys, buckets):
        iif_dict[key] = bucket
    temp_df = pd.DataFrame(iif_dict)

    # Cast our date columns as DateTime64 objects for ease of analysis.
    temp_df["Pay_Start"] = pd.to_datetime(temp_df["Pay_Start"])
    temp_df["Pay_End"] = pd.to_datetime(temp_df["Pay_End"])

    return temp_df

# %%
df = parse_iif("./merge/payroll_2022Q1.iif")
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
parse_iif("./merge/payroll_2022Q1.iif").tail(50)
# Out:
#                       Name  Pay_Start    Pay_End  Gross_Pay  Employer_Taxes  \
# 82        Hallin A. Burgan 2022-02-14 2022-02-20     194.00           17.03
# 83          Shelbey Easley 2022-02-14 2022-02-20     497.30           43.65
# 84        Gabriel Grabarek 2022-02-14 2022-02-20     239.38           21.02
# 85             John T. Key 2022-02-14 2022-02-20     673.08           59.09
# 86         Abigail C. Kopp 2022-02-14 2022-02-20     659.48           57.91
# 87     Carli A. Littlejohn 2022-02-14 2022-02-20     606.50           53.25
# 88            Monica Tirre 2022-02-14 2022-02-20     333.00           29.23
# 89         David J. Varwig 2022-02-14 2022-02-20     682.34           59.90
# 90        Michael S. Black 2022-02-21 2022-02-27     958.08           78.35
# 91          Rachel Browner 2022-02-21 2022-02-27    1582.00          129.37
# 92          Shelbey Easley 2022-02-21 2022-02-27     509.61           44.72
# 93        Gabriel Grabarek 2022-02-21 2022-02-27     225.98           19.83
# 94         Abigail C. Kopp 2022-02-21 2022-02-27     693.18           60.85
# 95     Carli A. Littlejohn 2022-02-21 2022-02-27     741.67           65.10
# 96   Isaiah Pasek-Santiago 2022-02-21 2022-02-27     103.20            9.06
# 97            Monica Tirre 2022-02-21 2022-02-27     335.00           29.40
# 98         David J. Varwig 2022-02-21 2022-02-27     695.80           61.07
# 99        Michael S. Black 2022-02-28 2022-03-06    1005.08           82.20
# 100         Rachel Browner 2022-02-28 2022-03-06    1625.00          132.89
# 101         Shelbey Easley 2022-02-28 2022-03-06     560.85           49.24
# 102       Gabriel Grabarek 2022-02-28 2022-03-06     103.75            9.10
# 103        Abigail C. Kopp 2022-02-28 2022-03-06     739.18           64.88
# 104    Carli A. Littlejohn 2022-02-28 2022-03-06     813.58           71.42
# 105  Isaiah Pasek-Santiago 2022-02-28 2022-03-06     138.25           12.13
# 106           Monica Tirre 2022-02-28 2022-03-06     475.00           41.70
# 107        David J. Varwig 2022-02-28 2022-03-06     811.61           71.25
# 108       Michael S. Black 2022-03-07 2022-03-13    1013.08           82.85
# 109         Rachel Browner 2022-03-07 2022-03-13     943.00           75.67
# 110         Shelbey Easley 2022-03-07 2022-03-13     555.08           48.72
# 111       Gabriel Grabarek 2022-03-07 2022-03-13     104.75            9.20
# 112        Abigail C. Kopp 2022-03-07 2022-03-13     755.18           66.30
# 113    Carli A. Littlejohn 2022-03-07 2022-03-13     819.58           71.93
# 114  Isaiah Pasek-Santiago 2022-03-07 2022-03-13     139.25           12.22
# 115           Monica Tirre 2022-03-07 2022-03-13     398.80           35.01
# 116        David J. Varwig 2022-03-07 2022-03-13     789.44           69.30
# 117       Michael S. Black 2022-03-14 2022-03-20     977.08           79.80
# 118         Rachel Browner 2022-03-14 2022-03-20    1532.00          117.20
# 119         Shelbey Easley 2022-03-14 2022-03-20     537.70           47.21
# 120        Abigail C. Kopp 2022-03-14 2022-03-20     759.90           66.68
# 121    Carli A. Littlejohn 2022-03-14 2022-03-20     809.76           67.70
# 122           Monica Tirre 2022-03-14 2022-03-20     356.60           31.30
# 123        David J. Varwig 2022-03-14 2022-03-20     769.68           65.01
# 124       Michael S. Black 2022-03-21 2022-03-27    1023.08           78.26
# 125         Rachel Browner 2022-03-21 2022-03-27    1737.80          132.94
# 126         Shelbey Easley 2022-03-21 2022-03-27     429.47           37.69
# 127       Gabriel Grabarek 2022-03-21 2022-03-27     112.22            9.86
# 128        Abigail C. Kopp 2022-03-21 2022-03-27     803.90           67.03
# 129    Carli A. Littlejohn 2022-03-21 2022-03-27     712.80           58.29
# 130           Monica Tirre 2022-03-21 2022-03-27     366.60           32.19
# 131        David J. Varwig 2022-03-21 2022-03-27     719.70           58.85
#
#      MO_Local_Tax  MO_Unemployment_Tax  Federal_Unemployment  MO_Income_Tax  \
# 82          -1.94                -1.02                 -1.17            0.0
# 83          -4.97                -2.62                 -2.99          -10.0
# 84          -2.39                -1.27                 -1.44            0.0
# 85          -6.73                -3.56                 -4.04          -19.0
# 86          -6.59                -3.49                 -3.96          -18.0
# 87          -6.07                -3.21                 -3.64          -15.0
# 88            NaN                -1.76                 -2.00           -2.0
# 89          -6.82                -3.60                 -4.10          -19.0
# 90          -9.58                -5.06                  0.00          -34.0
# 91            NaN                -8.35                  0.00          -67.0
# 92          -5.10                -2.69                 -3.05          -10.0
# 93          -2.26                -1.19                 -1.35            0.0
# 94          -6.93                -3.66                 -4.16          -20.0
# 95          -7.42                -3.91                 -4.45          -23.0
# 96          -1.03                -0.54                 -0.62            0.0
# 97            NaN                -1.76                 -2.01           -2.0
# 98          -6.96                -3.67                 -4.17          -20.0
# 99         -10.05                -5.31                  0.00          -37.0
# 100           NaN                -8.58                  0.00          -69.0
# 101         -5.61                -2.96                 -3.37          -13.0
# 102         -1.04                -0.55                 -0.62            0.0
# 103         -7.39                -3.90                 -4.43          -22.0
# 104         -8.14                -4.30                 -4.88          -26.0
# 105         -1.38                -0.73                 -0.83            0.0
# 106           NaN                -2.51                 -2.85           -8.0
# 107         -8.12                -4.29                 -4.87          -26.0
# 108        -10.13                -5.35                  0.00          -37.0
# 109           NaN                -3.53                  0.00          -33.0
# 110         -5.55                -2.93                 -3.33          -13.0
# 111         -1.05                -0.55                 -0.63            0.0
# 112         -7.55                -3.99                 -4.54          -23.0
# 113         -8.20                -4.32                 -4.92          -27.0
# 114         -1.39                -0.74                 -0.83            0.0
# 115           NaN                -2.11                 -2.39           -4.0
# 116         -7.89                -4.17                 -4.74          -25.0
# 117         -9.77                -5.05                  0.00          -35.0
# 118           NaN                 0.00                  0.00          -64.0
# 119         -5.38                -2.84                 -3.23          -12.0
# 120         -7.60                -4.01                 -4.55          -24.0
# 121         -8.10                -4.28                 -1.47          -26.0
# 122           NaN                -1.88                 -2.14           -3.0
# 123         -7.70                -4.06                 -2.07          -24.0
# 124        -10.23                 0.00                  0.00          -37.0
# 125           NaN                 0.00                  0.00          -75.0
# 126         -4.29                -2.27                 -2.57           -6.0
# 127         -1.12                -0.59                 -0.68            0.0
# 128         -8.04                -4.24                 -1.29          -26.0
# 129         -7.13                -3.76                  0.00          -21.0
# 130           NaN                -1.94                 -2.20           -3.0
# 131         -7.20                -3.80                  0.00          -21.0
#
#      Federal_Taxes
# 82          -29.68
# 83         -101.92
# 84          -36.62
# 85         -149.91
# 86         -146.22
# 87         -151.59
# 88          -59.34
# 89         -152.44
# 90         -237.64
# 91         -451.00
# 92         -105.28
# 93          -34.58
# 94         -155.41
# 95         -188.49
# 96          -15.80
# 97          -59.86
# 98         -156.12
# 99         -254.01
# 100        -467.04
# 101        -119.29
# 102         -15.86
# 103        -167.97
# 104        -208.12
# 105         -21.14
# 106         -95.84
# 107        -187.74
# 108        -256.99
# 109        -223.60
# 110        -117.69
# 111         -16.04
# 112        -172.33
# 113        -209.74
# 114         -21.30
# 115         -76.00
# 116        -181.68
# 117        -243.57
# 118        -432.36
# 119        -112.97
# 120        -173.59
# 121        -207.08
# 122         -65.32
# 123        -176.29
# 124        -260.71
# 125        -509.12
# 126         -83.74
# 127         -17.18
# 128        -185.63
# 129        -180.61
# 130         -67.86
# 131        -162.63

# %%
file_list = os.listdir('./Debug/')

# %%
#df = parse_iif("./merge/payroll_2016.iif")
file_list = os.listdir('./merge/')
df = parse_iif('payroll_2012.iif')
for file in file_list:
    path = './merge/'+file
    _df = parse_iif(path)

    df = pd.concat([df, _df], ignore_index=True)
# Out:
# (3306, 10)

# %%
df.describe()
# Out:
#          Gross_Pay  Employer_Taxes  MO_Local_Tax  MO_Unemployment_Tax  \
# count  3306.000000     3306.000000   2688.000000          2974.000000
# mean    660.596255       58.978001     -6.896455            -7.613594
# std     380.005428       34.490178      3.994209             9.471565
# min       2.170000        0.240000    -18.390000           -52.580000
# 25%     352.550000       33.075000     -8.750000           -10.835000
# 50%     635.425000       52.600000     -6.570000            -4.500000
# 75%     847.800000       76.507500     -4.230000             0.000000
# max    1838.670000      174.180000      0.000000             0.000000
#
#        Federal_Unemployment  MO_Income_Tax  Federal_Taxes
# count           2974.000000    3306.000000    3306.000000
# mean              -1.703406     -16.178766    -162.775923
# std                2.192191      14.690898     106.832170
# min              -10.360000     -75.000000    -539.480000
# 25%               -3.020000     -26.000000    -215.442500
# 50%               -0.550000     -13.000000    -150.830000
# 75%                0.000000      -2.000000     -75.357500
# max                0.000000       0.000000      -0.320000

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df.to_csv("payroll_complete_2012_2022Q1.csv")
